# %%
import pandas as pd
from pandasql import sqldf

# %%
df = pd.read_csv('heart_disease.csv')

# %%
describe_df = df.describe(include='all')

# %%
dtype = dict()
for column in df.columns:
    dtype[column] = str(pd.api.types.infer_dtype(df[column]))

# %%
dtype_df = pd.DataFrame.from_dict(dtype, orient='index', columns=["dtype"])

# %%
pd.concat([describe_df, dtype_df.T])
# Out:
#         Gender        age   education currentSmoker cigsPerDay    BPMeds  \
# count     4238     4238.0        4133        4238.0     4209.0    4185.0
# unique       2        NaN           4           NaN        NaN       NaN
# top     Female        NaN  uneducated           NaN        NaN       NaN
# freq      2419        NaN        1720           NaN        NaN       NaN
# mean       NaN  49.584946         NaN      0.494101   9.003089   0.02963
# std        NaN    8.57216         NaN      0.500024  11.920094  0.169584
# min        NaN       32.0         NaN           0.0        0.0       0.0
# 25%        NaN       42.0         NaN           0.0        0.0       0.0
# 50%        NaN       49.0         NaN           0.0        0.0       0.0
# 75%        NaN       56.0         NaN           1.0       20.0       0.0
# max        NaN       70.0         NaN           1.0       70.0       1.0
# dtype   string    integer      string       integer   floating  floating
#
# ...

# %%
sqldf('SELECT * FROM df', locals())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Ali\Desktop\Projects\Dataset_from_Scratch\api\venv\lib\site-packages\sqlalchemy\engine\base.py:1410, in Connection.execute(self, statement, parameters, execution_options)
#    1409 try:
# -> 1410     meth = statement._execute_on_connection
#    1411 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sqldf('SELECT * FROM df', locals())
#
# File c:\Users\Ali\Desktop\Projects\Dataset_from_Scratch\api\venv\lib\site-packages\pandasql\sqldf.py:156, in sqldf(query, env, db_uri)
#     124 def sqldf(query, env=None, db_uri='sqlite:///:memory:'):
#     125     """
# ...
